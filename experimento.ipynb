# %% [markdown]
# <a href="https://colab.research.google.com/github/brenda-gouveia/experimento_csi/blob/main/experimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import os
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.svm import SVC
from sklearn.decomposition import PCA
import pickle

# %%
path_amostra = '/content/drive/MyDrive/Colab Notebooks/experimento_csi'
filenames = os.listdir(path_amostra)
filenames[:5]
# Out:
# ['experimento.ipynb', '1_000.csv', '1_001.csv', '3_000.csv', '3_001.csv']
